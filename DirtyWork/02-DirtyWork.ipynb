# %%
import random

random_list = [random.random() for _ in range(5_000_000)]
print("Random list length: ", len(random_list))
# Out:
# Random list length:  5000000

# %%
def mean_custom(values):
    accumulate = 0
    for val in values:
        accumulate += val

    return accumulate / len(values)

def st_deviation(values):
    sd = 0
    mean_val = mean_custom(values)
    for val in values:
        sd += (val - mean_val) ** 2

    sd = (sd / len(values))

    return sd ** 0.5

# %%
print('Std: ', st_deviation(random_list))
# Out:
# Std:  0.28875123849196155

# %%
import numpy as np

np_array = np.array(random_list)

print('Std: ', np_array.std())
# Out:
# Std:  0.2887512384919565

# %%
import pandas as pd
import numpy as np
 
 
datos = pd.Series([10, 20, 30, 40, 50])
print("¡Entorno configurado con éxito!")
print(datos.describe())
# Out:
# ¡Entorno configurado con éxito!
# count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# dtype: float64

# %%
import pandas as pd
 
 
url = "https://raw.githubusercontent.com/mricardo89/data-mining/main/Unit-II/datasets/titanic.csv"
df = pd.read_csv(url)

df.head(5)
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 1. ¿Cuál es la diferencia matemática entre el percentil 75% (el tercer cuartil) y el valor Máximo (max)? Como ingenieros de software, ¿qué les dice esta enorme dispersión estadística sobre la homogeneidad de los precios que se cobraron en el barco?
#
# La diferencia que existe entre el percentil 75% y el valor maximo es de 481.32, ya que el 75% de los precios esta en 31, mientras que el precio maximo fue de 512.32, se puede concluir que los precios de los boletos fueron variados y no homogeneos, algunos pagaron cantidades bajas y otros más altas, ocasionando esta diferencia de precios por boleto de cada pasajero.

# %% [markdown]
# 2. Revisen la fila count (conteo total de registros válidos) de las distintas columnas en el resultado de su .describe(). Comparen el conteo de la columna PassengerId con el conteo de la columna Age. ¿Qué anomalía de base de datos acaban de descubrir?
#
# Existen datos faltantes de las edades de identificadores de pasajeros.
#
# Podría sospechar que no pudieron registrar las edades de ciertos pasajeros, una razon seria porque no exigian datos personales en esa epoca.

# %% [markdown]
# 3. El algoritmo que construirán al final del semestre requiere que todos los pasajeros tengan un valor numérico en la columna Age para poder compilar. Sabiendo lo que acaban de descubrir en la Pregunta B, propongan al menos dos estrategias a nivel de base de datos o de programación para resolver este problema antes de alimentar a la IA
#
# - Sacar el promedio de las edades existentes en la tabla para rellenar los datos faltantes, aunque no sean exactas, siempre es mejor tener datos en toda la tabla
#
# - Aplicar regresión lineal o KNN para predecir un numero usando otros datos, o buscar las personas mas parecidas en la tabla y copiar el dato faltante del vecino mas cercano
